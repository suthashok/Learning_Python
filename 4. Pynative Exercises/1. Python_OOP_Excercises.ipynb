# %% [markdown]
# https://pynative.com/python-object-oriented-programming-oop-exercise/

# %% [markdown]
# ![image.png](attachment:e82ede12-16fe-40c9-92fb-43dbe827c6f9.png)

# %%
class Vehicle:
    def __init__(self,max_speed,mileage):
        self.max_speed=max_speed
        self.mileage=mileage

# %%
modelX = Vehicle(240, 18)
print(modelX.max_speed, modelX.mileage)
# Out:
# 240 18

# %% [markdown]
# ![image.png](attachment:237e9fcc-d6f0-4c92-be38-3a7b88f682b9.png)

# %%
class Vehicle:
    def __init__(self):
        pass

# %% [markdown]
# ![image.png](attachment:711be959-ae24-4b2e-8799-0d427965f75f.png)

# %%
class Vehicle:

    def __init__(self,name,max_speed,mileage):
        self.name=name
        self.max_speed=max_speed
        self.mileage=mileage

class Bus(Vehicle):
    def __init__(self):
        Vehicle.__init__(self,self.name,self.max_speed,self.mileage)


#Another Simple Implementation
#class Bus(Vehicle):
#        pass

# %%
b=Vehicle(name='School Volvo',max_speed=180,mileage=12)

# %%
print('Vehicle name: ',b.name,' Speed: ',b.max_speed,' Mileage: ',b.mileage)
# Out:
# Vehicle name:  School Volvo  Speed:  180  Mileage:  12

# %% [markdown]
# ![image.png](attachment:39281432-97d8-4292-933a-56c9963611d5.png)

# %%
class Vehicle:
    def __init__(self,name,max_speed,mileage):
        self.name=name
        self.max_speed=max_speed
        self.mileage=mileage
    
    def seating_capacity(self,capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers."

class Bus(Vehicle):
    #Overiding a metod defined in parent class
    def seating_capacity(self, capacity=50):
        return super().seating_capacity(capacity=50) #Using Super to take it from parent class

# %%
a=Bus('Bus',10,50)
a.seating_capacity()
# Out:
# 'The seating capacity of a Bus is 50 passengers.'

# %% [markdown]
# ![image.png](attachment:9ce615b6-251d-4cce-9e8f-832b1b1be4c9.png)

# %%
class Vehicle:
    color='White' #Class Attributes
    def __init__(self,name,max_speed,mileage):
        self.name=name
        self.max_speed=max_speed
        self.mileage=mileage
    
    def seating_capacity(self,capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers."

class Bus(Vehicle):
    pass
class Car(Vehicle):
    pass

# %%
b=Vehicle(name='School Volvo',max_speed=180,mileage=12)
c=Vehicle(name='Audi Q5',max_speed=240,mileage=18)

# %%
print('Color: ', b.color, ', Vehicle name: ',b.name,', Speed: ',b.max_speed,', Mileage: ',b.mileage)
# Out:
# Color:  White , Vehicle name:  School Volvo , Speed:  180 , Mileage:  12

# %%
print('Color: ', c.color, ', Vehicle name: ',c.name,', Speed: ',c.max_speed,', Mileage: ',c.mileage)
# Out:
# Color:  White , Vehicle name:  Audi Q5 , Speed:  240 , Mileage:  18

# %% [markdown]
# # End
