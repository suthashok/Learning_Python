# %% [markdown]
# ## Python Data Types & Mathematical Operations

# %% [markdown]
# !![image.png](attachment:16c481ab-883d-4995-a2ee-6a8f0d65ac8f.png)

# %%
bill_amt=float(input('What is the total bill amount?\n$:'))
tip_perc=int(input('How much tip would you like to give?\nPercent:'))
num_people=int(input('How many people to split the bill?\nPeople:'))
print('Each person should pay: $',round(bill_amt*(1+tip_perc/100.0)/num_people,2),sep='')
# Out:
# What is the total bill amount?
# $: 80.02
# How much tip would you like to give?
# Percent: 15
# How many people to split the bill?
# People: 4
# Each person should pay: $23.01

# %%
#### End
