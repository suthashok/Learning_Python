# %% [markdown]
# ## Python Variables & Input Output

# %% [markdown]
# !![image.png](attachment:1f91eaf0-aa5a-4e5f-bd2d-aff7fa4154c6.png)

# %%
city_name=input('What city did you grow up in?')
pet_name=input('What is the name of your first pet?')
print('You brand name is',city_name,pet_name,'.')
# Out:
# What city did you grow up in? Toronto
# What is the name of your first pet? Gecko
# You brand name is Toronto Gecko .

# %%
#### End
